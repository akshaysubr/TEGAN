# %%
import numpy
import matplotlib.pyplot as plt
import sys

sys.path.insert(0, "../figures/")

import readTFevents

# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'cm'

# %config InlineBackend.figure_format = 'svg'

# import matplotlib as mpl
# mpl.rcParams['text.usetex'] = True
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1620888907.5138dcdc2bb5"
file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1620888905.5138dcdc2bb5"

file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1620894324.5138dcdc2bb5"
file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1620894322.5138dcdc2bb5"

file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1620894324.5138dcdc2bb5"
file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1620894322.5138dcdc2bb5"

# file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1621212324.regulus"
# file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1621212322.regulus"

# file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1622498183.regulus"
# file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1622498181.regulus"

# file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1622498945.11f2c976cbfb"
# file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1622498943.11f2c976cbfb"

# file_name_TEGAN_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/dev/events.out.tfevents.1622499272.11f2c976cbfb"
# file_name_TEGAN_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000_GS300_GF2_AR0.01_DR0.5_DS400_STR-True/train/events.out.tfevents.1622499270.11f2c976cbfb"


file_name_TEGAN_lambda_p_0_125_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS400_STR-True-rev/dev/events.out.tfevents.1622529606.33f99542d144"
file_name_TEGAN_lambda_p_0_125_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS400_STR-True-rev/train/events.out.tfevents.1622529604.33f99542d144"

# file_name_TEGAN_lambda_p_0_125_dev   = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS400_STR-True-rev/dev/events.out.tfevents.1622693536.ea609c340170"
# file_name_TEGAN_lambda_p_0_125_train = "/home/manlong/IPython_Notebook/TEGAN/TEGAN/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS400_STR-True-rev/train/events.out.tfevents.1622693534.ea609c340170"


TEGAN_tags = readTFevents.get_tags_from_event(file_name_TEGAN_lambda_p_0_000_dev)

# %%
TEGAN_tags
# Out:
# ['High_resolution/image/0',
#  'Low_resolution/image/0',
#  'Generated/image/0',
#  'Concat/image/0',
#  'Generator_loss',
#  'Adversarial_loss',
#  'Content_loss',
#  'Physics_loss',
#  'MSE_error',
#  'Continuity_error',
#  'Pressure_error',
#  'TKE_error',
#  'Enstrophy_error',
#  'Z_-_Continuity_residual/image/0',
#  'Z_-_Pressure_residual/image/0',
#  'Discriminator_loss',
#  'Discriminator_fake_output',
#  'Learning_rate']

# %%
train = numpy.arange(1800)*2000.0/1800.0

# %%
TEGAN_learning_rate_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Learning_rate')
TEGAN_learning_rate_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Learning_rate')

TEGAN_learning_rate_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Learning_rate')
TEGAN_learning_rate_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Learning_rate')

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_learning_rate_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_learning_rate_labmda_p_0_000_train, '-', label=r'$\lambda_P=0$')
# plt.plot(TEGAN_learning_rate_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_learning_rate_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')

# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_P=0$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_P=0.25$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathrm{Learning\ rate}$', fontsize=20)
# plt.ylabel(r'$\mathrm{Continuity\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.01, 0.15)

plt.tight_layout()
plt.show()

# %%
TEGAN_continuity_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Continuity_error')
TEGAN_continuity_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Continuity_error')

TEGAN_continuity_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Continuity_error')
TEGAN_continuity_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Continuity_error')

TEGAN_continuity_loss_labmda_p_0_000_dev = numpy.square(numpy.array(TEGAN_continuity_loss_labmda_p_0_000_dev))
TEGAN_continuity_loss_labmda_p_0_125_dev = numpy.square(numpy.array(TEGAN_continuity_loss_labmda_p_0_125_dev))

TEGAN_continuity_loss_labmda_p_0_000_train = numpy.square(numpy.array(TEGAN_continuity_loss_labmda_p_0_000_train))
TEGAN_continuity_loss_labmda_p_0_125_train = numpy.square(numpy.array(TEGAN_continuity_loss_labmda_p_0_125_train))

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_continuity_loss_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_continuity_loss_labmda_p_0_000_train, 'r-', linewidth=1.5, label=r'$\lambda_P=0$')
# plt.plot(TEGAN_continuity_loss_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_continuity_loss_labmda_p_0_125_train, 'b--', linewidth=1.5, label=r'$\lambda_P=0.125=$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{continuity}$', fontsize=20)
# plt.ylabel(r'$\mathrm{Continuity\ error}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.00005, 0.0005)
# plt.ylim(-0.0, 0.002)

plt.tight_layout()
# plt.savefig('TEGAN_continuity_loss.pdf')
plt.show()

# %%
TEGAN_pressure_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Pressure_error')
TEGAN_pressure_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Pressure_error')

TEGAN_pressure_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Pressure_error')
TEGAN_pressure_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Pressure_error')

TEGAN_pressure_loss_labmda_p_0_000_dev = numpy.square(numpy.array(TEGAN_pressure_loss_labmda_p_0_000_dev))
TEGAN_pressure_loss_labmda_p_0_125_dev = numpy.square(numpy.array(TEGAN_pressure_loss_labmda_p_0_125_dev))

TEGAN_pressure_loss_labmda_p_0_000_train = numpy.square(numpy.array(TEGAN_pressure_loss_labmda_p_0_000_train))
TEGAN_pressure_loss_labmda_p_0_125_train = numpy.square(numpy.array(TEGAN_pressure_loss_labmda_p_0_125_train))

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_pressure_loss_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_pressure_loss_labmda_p_0_000_train, 'r-', linewidth=1.5, label=r'$\lambda_P=0$')
# plt.plot(TEGAN_pressure_loss_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_pressure_loss_labmda_p_0_125_train, 'b--', linewidth=1.5, label=r'$\lambda_P=0.125=$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{pressure}$', fontsize=20)
# plt.ylabel(r'$\mathrm{pressure\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.00005, 0.0005)
plt.ylim(-0.0, 0.2)

plt.tight_layout()
# plt.savefig('TEGAN_pressure_loss.pdf')
plt.show()

# %%
TEGAN_content_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Content_loss')
TEGAN_content_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Content_loss')

TEGAN_content_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Content_loss')
TEGAN_content_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Content_loss')

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_content_loss_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_content_loss_labmda_p_0_000_train, 'r-', linewidth=1.5, label=r'$\lambda_P=0$')
# plt.plot(TEGAN_content_loss_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_content_loss_labmda_p_0_125_train, 'b--', linewidth=1.5, label=r'$\lambda_P=0.125$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{content}$', fontsize=20)
# plt.ylabel(r'$\mathrm{content\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.00005, 0.0005)
plt.ylim(6.0e-3, 0.011)

plt.tight_layout()
plt.savefig('TEGAN_content_loss.pdf')
plt.show()

# %%
TEGAN_physics_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Physics_loss')
TEGAN_physics_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Physics_loss')

TEGAN_physics_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Physics_loss')
TEGAN_physics_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Physics_loss')

TEGAN_physics_loss_labmda_p_0_000_dev   = 0.1*TEGAN_pressure_loss_labmda_p_0_000_dev + 0.9*TEGAN_continuity_loss_labmda_p_0_000_dev
TEGAN_physics_loss_labmda_p_0_000_train = 0.1*TEGAN_pressure_loss_labmda_p_0_000_train + 0.9*TEGAN_continuity_loss_labmda_p_0_000_train

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_physics_loss_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_physics_loss_labmda_p_0_000_train, 'r-', linewidth=1.5, label=r'$\lambda_P=0$')
# plt.plot(TEGAN_physics_loss_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_physics_loss_labmda_p_0_125_train, 'b--', linewidth=1.5, label=r'$\lambda_P=0.125$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
# plt.ylabel(r'$\mathrm{physics\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.00005, 0.0005)
plt.ylim(5.0e-3, 12.0e-3)

plt.tight_layout()
plt.savefig('TEGAN_physics_loss.pdf')
plt.show()

# %%
TEGAN_discriminator_fake_output_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_dev, tag='Discriminator_fake_output')
TEGAN_discriminator_fake_output_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_000_train, tag='Discriminator_fake_output')

TEGAN_discriminator_fake_output_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_dev, tag='Discriminator_fake_output')
TEGAN_discriminator_fake_output_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEGAN_lambda_p_0_125_train, tag='Discriminator_fake_output')

plt.figure(figsize=(6,4))
# plt.plot(TEGAN_discriminator_fake_output_labmda_p_0_000_dev, '-',  label=r'$\lambda_P=0,\ dev$')
plt.plot(train, TEGAN_discriminator_fake_output_labmda_p_0_000_train, 'r-', linewidth=1.5, label=r'$\lambda_P=0$')
# plt.plot(TEGAN_discriminator_fake_output_labmda_p_0_125_dev, '--',  label=r'$\lambda_P=0.125,\ dev$')
plt.plot(train, TEGAN_discriminator_fake_output_labmda_p_0_125_train, 'b--', linewidth=1.5, label=r'$\lambda_P=0.125$')

plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$D(G(I^{LR}))$', fontsize=20)
# plt.ylabel(r'$\mathrm{physics\ error}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(0.0, 1.0)

plt.tight_layout()
plt.savefig('TEGAN_discriminator_fake_output.pdf')
plt.show()
