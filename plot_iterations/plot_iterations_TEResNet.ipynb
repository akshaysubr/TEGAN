# %%
import numpy
import matplotlib.pyplot as plt
import sys

sys.path.insert(0, "../figures/")

import readTFevents

# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'cm'

# %config InlineBackend.figure_format = 'svg'

import matplotlib as mpl
# mpl.rcParams['text.usetex'] = True
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

mpl.style.use('classic')
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler(color='rbgkcmy')
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# file_name_TEResNet_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/dev/events.out.tfevents.1620008451.deagle"
# file_name_TEResNet_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/train/events.out.tfevents.1620008449.deagle"

# file_name_TEResNet_lambda_p_0_125_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/dev/events.out.tfevents.1620142609.deagle"
# file_name_TEResNet_lambda_p_0_125_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/train/events.out.tfevents.1620142607.deagle"

# file_name_TEResNet_lambda_p_0_250_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.250/dev/events.out.tfevents.1620069407.deagle"
# file_name_TEResNet_lambda_p_0_250_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.250/train/events.out.tfevents.1620069405.deagle"

# file_name_TEResNet_lambda_p_0_500_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.500/dev/events.out.tfevents.1620227197.deagle"
# file_name_TEResNet_lambda_p_0_500_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.500/train/events.out.tfevents.1620227195.deagle"

# TEResNet_tags = readTFevents.get_tags_from_event(file_name_TEResNet_lambda_p_0_125_dev)

# %%
file_name_TEResNet_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/dev/events.out.tfevents.1620008451.deagle"
file_name_TEResNet_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/train/events.out.tfevents.1620008449.deagle"

file_name_TEResNet_lambda_p_0_125_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125/dev/events.out.tfevents.1621570036.deagle"
file_name_TEResNet_lambda_p_0_125_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.125/train/events.out.tfevents.1621570035.deagle"

file_name_TEResNet_lambda_p_0_250_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.250/dev/events.out.tfevents.1621225612.deagle"
file_name_TEResNet_lambda_p_0_250_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.250/train/events.out.tfevents.1621225610.deagle"

file_name_TEResNet_lambda_p_0_500_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.500/dev/events.out.tfevents.1622005940.deagle"
file_name_TEResNet_lambda_p_0_500_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500_con_0_9/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.9_PHY0.500/train/events.out.tfevents.1622005938.deagle"

TEResNet_tags = readTFevents.get_tags_from_event(file_name_TEResNet_lambda_p_0_125_dev)

# %%
TEResNet_tags
# Out:
# ['High_resolution/image/0',
#  'Low_resolution/image/0',
#  'Generated/image/0',
#  'Concat/image/0',
#  'Generator_loss',
#  'Content_loss',
#  'Physics_loss',
#  'MSE_error',
#  'Continuity_error',
#  'Pressure_error',
#  'TKE_error',
#  'Enstrophy_error',
#  'Z_-_Continuity_residual/image/0',
#  'Z_-_Pressure_residual/image/0',
#  'Learning_rate']

# %%
TEResNet_continuity_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Continuity_error')
TEResNet_continuity_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Continuity_error')

TEResNet_continuity_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Continuity_error')
TEResNet_continuity_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Continuity_error')

TEResNet_continuity_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Continuity_error')
TEResNet_continuity_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Continuity_error')

TEResNet_continuity_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Continuity_error')
TEResNet_continuity_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Continuity_error')

TEResNet_continuity_loss_labmda_p_0_000_dev = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_000_dev))
TEResNet_continuity_loss_labmda_p_0_125_dev = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_125_dev))
TEResNet_continuity_loss_labmda_p_0_250_dev = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_250_dev))
TEResNet_continuity_loss_labmda_p_0_500_dev = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_500_dev))

TEResNet_continuity_loss_labmda_p_0_000_train = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_000_train))
TEResNet_continuity_loss_labmda_p_0_125_train = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_125_train))
TEResNet_continuity_loss_labmda_p_0_250_train = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_250_train))
TEResNet_continuity_loss_labmda_p_0_500_train = numpy.square(numpy.array(TEResNet_continuity_loss_labmda_p_0_500_train))

plt.figure(figsize=(6,4))
plt.plot(TEResNet_continuity_loss_labmda_p_0_000_train, '-',  linewidth=1.5, label=r'$\lambda_P=0$')
plt.plot(TEResNet_continuity_loss_labmda_p_0_125_train, '--', linewidth=1.5, label=r'$\lambda_P=0.125$')
plt.plot(TEResNet_continuity_loss_labmda_p_0_250_train, '-.', linewidth=1.5, label=r'$\lambda_P=0.25$')
plt.plot(TEResNet_continuity_loss_labmda_p_0_500_train, ':',  linewidth=1.5, label=r'$\lambda_P=0.5$')

# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_P=0$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_P=0.25$')
# plt.semilogy(TEResNet_continuity_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{continuity}$', fontsize=20)
# plt.ylabel(r'$\mathrm{Continuity\ error}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.0005, 0.005)
# plt.ylim(-0.0, 0.002)
plt.xlim(-100, 2300)

plt.tight_layout()
plt.savefig('TEResNet_continuity_loss.pdf')
plt.show()

# %%
TEResNet_pressure_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Pressure_error')
TEResNet_pressure_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Pressure_error')

TEResNet_pressure_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Pressure_error')
TEResNet_pressure_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Pressure_error')

TEResNet_pressure_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Pressure_error')
TEResNet_pressure_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Pressure_error')

TEResNet_pressure_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Pressure_error')
TEResNet_pressure_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Pressure_error')

TEResNet_pressure_loss_labmda_p_0_000_dev = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_000_dev))
TEResNet_pressure_loss_labmda_p_0_125_dev = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_125_dev))
TEResNet_pressure_loss_labmda_p_0_250_dev = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_250_dev))
TEResNet_pressure_loss_labmda_p_0_500_dev = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_500_dev))

TEResNet_pressure_loss_labmda_p_0_000_train = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_000_train))
TEResNet_pressure_loss_labmda_p_0_125_train = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_125_train))
TEResNet_pressure_loss_labmda_p_0_250_train = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_250_train))
TEResNet_pressure_loss_labmda_p_0_500_train = numpy.square(numpy.array(TEResNet_pressure_loss_labmda_p_0_500_train))

plt.figure(figsize=(6,4))
# plt.plot(TEResNet_pressure_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_P=0$')
# plt.plot(TEResNet_pressure_loss_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')
# plt.plot(TEResNet_pressure_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_P=0.25$')
# plt.plot(TEResNet_pressure_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_P=0.5$')

plt.semilogy(TEResNet_pressure_loss_labmda_p_0_000_train, '-',  linewidth=1.5, label=r'$\lambda_P=0$')
plt.semilogy(TEResNet_pressure_loss_labmda_p_0_125_train, '--', linewidth=1.5, label=r'$\lambda_P=0.125$')
plt.semilogy(TEResNet_pressure_loss_labmda_p_0_250_train, '-.', linewidth=1.5, label=r'$\lambda_P=0.25$')
plt.semilogy(TEResNet_pressure_loss_labmda_p_0_500_train, ':',  linewidth=1.5, label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{pressure}$', fontsize=20)
# plt.ylabel(r'$\mathrm{Pressure\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.1, 2.0)
plt.ylim(2.0e-2, 2.0e0)
plt.xlim(-100, 2300)

plt.tight_layout()
plt.savefig('TEResNet_pressure_loss.pdf')
plt.show()

# %%
TEResNet_physics_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Physics_loss')
TEResNet_physics_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Physics_loss')

TEResNet_physics_loss_labmda_p_0_000_dev   = 0.1*TEResNet_pressure_loss_labmda_p_0_000_dev + 0.9*TEResNet_continuity_loss_labmda_p_0_000_dev
TEResNet_physics_loss_labmda_p_0_000_train = 0.1*TEResNet_pressure_loss_labmda_p_0_000_train + 0.9*TEResNet_continuity_loss_labmda_p_0_000_train

TEResNet_physics_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Physics_loss')
TEResNet_physics_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Physics_loss')

TEResNet_physics_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Physics_loss')
TEResNet_physics_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Physics_loss')

TEResNet_physics_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Physics_loss')
TEResNet_physics_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
# plt.plot(TEResNet_physics_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_P=0$')
# plt.plot(TEResNet_physics_loss_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')
# plt.plot(TEResNet_physics_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_P=0.25$')
# plt.plot(TEResNet_physics_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_P=0.5$')

plt.semilogy(TEResNet_physics_loss_labmda_p_0_000_train, '-',  linewidth=1.5, label=r'$\lambda_P=0$')
plt.semilogy(TEResNet_physics_loss_labmda_p_0_125_train, '--', linewidth=1.5, label=r'$\lambda_P=0.125$')
plt.semilogy(TEResNet_physics_loss_labmda_p_0_250_train, '-.', linewidth=1.5, label=r'$\lambda_P=0.25$')
plt.semilogy(TEResNet_physics_loss_labmda_p_0_500_train, ':',  linewidth=1.5, label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(-0.01, 0.2)
plt.ylim(1.0e-3, 1.0e0)
plt.xlim(-100, 2300)

plt.tight_layout()
plt.savefig('TEResNet_physics_loss.pdf')
plt.show()

# %%
print(TEResNet_physics_loss_labmda_p_0_125_train[-1])
print(TEResNet_pressure_loss_labmda_p_0_125_train[-1]*TEResNet_pressure_loss_labmda_p_0_125_train[-1]*0.1)
print(TEResNet_continuity_loss_labmda_p_0_125_train[-1]*TEResNet_continuity_loss_labmda_p_0_125_train[-1]*0.9)
# Out:
# 0.006849239580333233
# 0.0004499235341358898
# 2.2280098916985133e-08

# %%
print(TEResNet_pressure_loss_labmda_p_0_000_train[-1])
print(TEResNet_continuity_loss_labmda_p_0_000_train[-1])
# Out:
# 0.08937376738683245
# 0.00038048388998070115

# %%
TEResNet_content_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Content_loss')
TEResNet_content_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Content_loss')

TEResNet_content_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Content_loss')
TEResNet_content_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Content_loss')

TEResNet_content_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Content_loss')
TEResNet_content_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Content_loss')

TEResNet_content_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Content_loss')
TEResNet_content_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Content_loss')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_content_loss_labmda_p_0_000_train, '-',  linewidth=1.5, label=r'$\lambda_P=0$')
plt.plot(TEResNet_content_loss_labmda_p_0_125_train, '--', linewidth=1.5, label=r'$\lambda_P=0.125$')
plt.plot(TEResNet_content_loss_labmda_p_0_250_train, '-.', linewidth=1.5, label=r'$\lambda_P=0.25$')
plt.plot(TEResNet_content_loss_labmda_p_0_500_train, ':',  linewidth=1.5, label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{content}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.01, 0.15)
plt.xlim(-100, 2300)

plt.tight_layout()
plt.savefig('TEResNet_content_loss.pdf')
plt.show()

# %%
TEResNet_TKE_error_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='TKE_error')
TEResNet_TKE_error_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='TKE_error')

TEResNet_TKE_error_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='TKE_error')
TEResNet_TKE_error_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='TKE_error')

TEResNet_TKE_error_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='TKE_error')
TEResNet_TKE_error_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='TKE_error')

TEResNet_TKE_error_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='TKE_error')
TEResNet_TKE_error_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='TKE_error')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_TKE_error_labmda_p_0_000_train, '-',  label=r'$\lambda_P=0$')
plt.plot(TEResNet_TKE_error_labmda_p_0_125_train, '--', label=r'$\lambda_P=0.125$')
plt.plot(TEResNet_TKE_error_labmda_p_0_250_train, '-.', label=r'$\lambda_P=0.25$')
plt.plot(TEResNet_TKE_error_labmda_p_0_500_train, ':',  label=r'$\lambda_P=0.5$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathrm{TKE\ error}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.01, 0.5)
plt.xlim(-100, 2300)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()
