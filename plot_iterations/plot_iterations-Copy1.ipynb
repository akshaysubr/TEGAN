# %%
import numpy
import matplotlib.pyplot as plt
import sys

sys.path.insert(0, "../figures/")

import readTFevents

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

# %%
filename_TEResNet_short_dev   = "/home/manlong/IPython_Notebook/TEGAN/short/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/dev/events.out.tfevents.1617578829.deagle"
filename_TEResNet_short_train = "/home/manlong/IPython_Notebook/TEGAN/short/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/train/events.out.tfevents.1617578827.deagle"

filename_TEGAN_short_dev   = "/home/manlong/IPython_Notebook/TEGAN/short/TEGAN-short/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS600_STR-True/dev/events.out.tfevents.1618293471.6496de084a1e"
filename_TEGAN_short_train = "/home/manlong/IPython_Notebook/TEGAN/short/TEGAN-short/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS600_STR-True/train/events.out.tfevents.1618293469.6496de084a1e"

filename_TEResNet_long_dev   = "/home/manlong/IPython_Notebook/TEGAN/long/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/dev/events.out.tfevents.1617605287.deagle"
filename_TEResNet_long_train = "/home/manlong/IPython_Notebook/TEGAN/long/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/train/events.out.tfevents.1617605286.deagle"

filename_TEGAN_long_dev   = "/home/manlong/IPython_Notebook/TEGAN/long/TEGAN-long/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS600_STR-True/dev/events.out.tfevents.1618298768.6496de084a1e"
filename_TEGAN_long_train = "/home/manlong/IPython_Notebook/TEGAN/long/TEGAN-long/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125_GS300_GF2_AR0.01_DR0.5_DS600_STR-True/train/events.out.tfevents.1618298766.6496de084a1e"

filename_TEResNet_short_no_physics_loss_dev   = "/home/manlong/IPython_Notebook/TEGAN/short_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.0/dev/events.out.tfevents.1619461825.deagle"
filename_TEResNet_short_no_physics_loss_train = "/home/manlong/IPython_Notebook/TEGAN/short_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.0/train/events.out.tfevents.1619461823.deagle"

filename_TEResNet_long_no_physics_loss_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.0/dev/events.out.tfevents.1619397931.deagle"
filename_TEResNet_long_no_physics_loss_train = "/home/manlong/IPython_Notebook/TEGAN/long_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.0/train/events.out.tfevents.1619397930.deagle"


TEResNet_tags = readTFevents.get_tags_from_event(filename_TEResNet_short_dev)
TEGAN_tags    = readTFevents.get_tags_from_event(filename_TEGAN_short_dev)

# %%
TEResNet_tags
# Out:
# ['High_resolution/image/0',
#  'Low_resolution/image/0',
#  'Generated/image/0',
#  'Concat/image/0',
#  'Generator_loss',
#  'Content_loss',
#  'Physics_loss',
#  'MSE_error',
#  'Continuity_error',
#  'Pressure_error',
#  'TKE_error',
#  'Enstrophy_error',
#  'Z_-_Continuity_residual/image/0',
#  'Z_-_Pressure_residual/image/0',
#  'Learning_rate']

# %%
TEGAN_tags
# Out:
# ['High_resolution/image/0',
#  'Low_resolution/image/0',
#  'Generated/image/0',
#  'Concat/image/0',
#  'Generator_loss',
#  'Adversarial_loss',
#  'Content_loss',
#  'Physics_loss',
#  'MSE_error',
#  'Continuity_error',
#  'Pressure_error',
#  'TKE_error',
#  'Enstrophy_error',
#  'Z_-_Continuity_residual/image/0',
#  'Z_-_Pressure_residual/image/0',
#  'Discriminator_loss',
#  'Discriminator_fake_output',
#  'Learning_rate']

# %% [markdown]
# # Short

# %%
TEResNet_short_dev_generator_loss   = readTFevents.read_summary_value(filename_TEResNet_short_dev, tag='Generator_loss')
TEResNet_short_train_generator_loss = readTFevents.read_summary_value(filename_TEResNet_short_train, tag='Generator_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_short_dev_generator_loss, '-', label=r'$\mathrm{dev}$')
plt.semilogy(TEResNet_short_train_generator_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{ResNet}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()

# %%
TEResNet_short_dev_physics_loss   = readTFevents.read_summary_value(filename_TEResNet_short_dev, tag='Physics_loss')
TEResNet_short_train_physics_loss = readTFevents.read_summary_value(filename_TEResNet_short_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_short_dev_physics_loss, '-', label=r'$\mathrm{dev}$')
plt.semilogy(TEResNet_short_train_physics_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()

# %%
TEResNet_short_no_physics_loss_train_physics_loss   = readTFevents.read_summary_value(filename_TEResNet_short_no_physics_loss_train, tag='Physics_loss')
TEResNet_long_no_physics_loss_train_physics_loss    = readTFevents.read_summary_value(filename_TEResNet_long_no_physics_loss_train, tag='Physics_loss')


TEResNet_short_train_physics_loss   = readTFevents.read_summary_value(filename_TEResNet_short_train, tag='Physics_loss')
TEResNet_long_train_physics_loss    = readTFevents.read_summary_value(filename_TEResNet_long_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_short_no_physics_loss_train_physics_loss, '-', label=r'$\lambda_p=0.0,\ \mathrm{short}$')
plt.semilogy(TEResNet_long_no_physics_loss_train_physics_loss, ':', label=r'$\lambda_p=0.0,\ \mathrm{long}$')
plt.semilogy(TEResNet_short_train_physics_loss, '-', label=r'$\lambda_p=0.125,\ \mathrm{short}$')
plt.semilogy(TEResNet_long_train_physics_loss, ':', label=r'$\lambda_p=0.125,\ \mathrm{long}$')
plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()

# %%
TEGAN_short_dev_physics_loss   = readTFevents.read_summary_value(filename_TEGAN_short_dev, tag='Physics_loss')
TEGAN_short_train_physics_loss = readTFevents.read_summary_value(filename_TEGAN_short_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEGAN_short_dev_physics_loss, '-', label=r'$\mathrm{dev}$')
# plt.semilogy(TEGAN_short_train_physics_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.ylim([4.0e-2, 6.0e-2])
plt.show()

# %%
# Out:
# 0.026804493553936482
# 0.026442250795662404

# %%
TEGAN_short_dev_dis_fake_output   = readTFevents.read_summary_value(filename_TEGAN_short_dev, tag='Discriminator_fake_output')
TEGAN_short_train_dis_fake_output = readTFevents.read_summary_value(filename_TEGAN_short_train, tag='Discriminator_fake_output')

plt.figure(figsize=(6,4))
plt.plot(TEGAN_short_dev_dis_fake_output, '-', label=r'$\mathrm{dev}$')
plt.plot(TEGAN_short_train_dis_fake_output, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$D(G(I^{LR}))$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.show()

# %%
TEGAN_long_train_summary = readTFevents.read_summaryall_value(filename_TEGAN_long_train)
TEGAN_long_dev_summary   = readTFevents.read_summaryall_value(filename_TEGAN_long_dev)

# %%
len(TEGAN_long_dev_summary['Learning_rate'])
# Out:
# 2000

# %% [markdown]
# # long

# %%
TEResNet_long_dev_generator_loss   = readTFevents.read_summary_value(filename_TEResNet_long_dev, tag='Generator_loss')
TEResNet_long_train_generator_loss = readTFevents.read_summary_value(filename_TEResNet_long_train, tag='Generator_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_long_dev_generator_loss, '-', label=r'$\mathrm{dev}$')
plt.semilogy(TEResNet_long_train_generator_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{ResNet}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()

# %%
TEResNet_long_dev_physics_loss   = readTFevents.read_summary_value(filename_TEResNet_long_dev, tag='Physics_loss')
TEResNet_long_train_physics_loss = readTFevents.read_summary_value(filename_TEResNet_long_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_long_dev_physics_loss, '-', label=r'$\mathrm{dev}$')
plt.semilogy(TEResNet_long_train_physics_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()

# %%
TEResNet_long_train_physics_loss[500]
# Out:
# 0.07889655977487564

# %%
TEGAN_long_train_physics_loss = readTFevents.read_summary_value(filename_TEGAN_long_train, tag='Physics_loss')
TEGAN_long_dev_physics_loss   = readTFevents.read_summary_value(filename_TEGAN_long_dev, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEGAN_long_dev_physics_loss, '-', label=r'$\mathrm{dev}$')
plt.semilogy(TEGAN_long_train_physics_loss, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.ylim([1.5e-2, 2.0e-1])
plt.show()

# %%
TEGAN_long_dev_dis_fake_output   = readTFevents.read_summary_value(filename_TEGAN_long_dev, tag='Discriminator_fake_output')
TEGAN_long_train_dis_fake_output = readTFevents.read_summary_value(filename_TEGAN_long_train, tag='Discriminator_fake_output')

plt.figure(figsize=(6,4))
plt.plot(TEGAN_long_dev_dis_fake_output, '-', label=r'$\mathrm{dev}$')
plt.plot(TEGAN_long_train_dis_fake_output, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$D(G(I^{LR}))$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.show()

# %%
TEGAN_long_dev_learning_rate   = readTFevents.read_summary_value(filename_TEGAN_long_dev, tag='Learning_rate')
TEGAN_long_train_learning_rate = readTFevents.read_summary_value(filename_TEGAN_long_train, tag='Learning_rate')

plt.figure(figsize=(6,4))
plt.plot(TEGAN_long_dev_learning_rate, '-', label=r'$\mathrm{dev}$')
plt.plot(TEGAN_long_train_learning_rate, ':', label=r'$\mathrm{train}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathrm{Learning\ rate}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.show()

# %%
TEResNet_long_dev_content_loss = readTFevents.read_summary_value(filename_TEResNet_long_dev, tag='Content_loss')
TEGAN_long_dev_content_loss  = readTFevents.read_summary_value(filename_TEGAN_long_dev, tag='Content_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_long_dev_content_loss, '-', label=r'$\mathrm{TEResNet}$')
plt.semilogy(TEGAN_long_dev_content_loss, ':', label=r'$\mathrm{TEGAN}$')
plt.xlabel(r'$\mathrm{Iterations}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{content}$', fontsize=20)
plt.legend(fontsize=14)
# plt.title(r'$\mathrm{TEGAN}$',fontsize=16)
plt.ylim([1.0e-2, 2.0e-2])
plt.show()
