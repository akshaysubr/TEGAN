# %%
import numpy
import matplotlib.pyplot as plt
import sys

sys.path.insert(0, "../figures/")

import readTFevents

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
file_name_TEResNet_lambda_p_0_000_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/dev/events.out.tfevents.1620008451.deagle"
file_name_TEResNet_lambda_p_0_000_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_000/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.000/train/events.out.tfevents.1620008449.deagle"

file_name_TEResNet_lambda_p_0_125_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/dev/events.out.tfevents.1620142609.deagle"
file_name_TEResNet_lambda_p_0_125_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_125/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.125/train/events.out.tfevents.1620142607.deagle"

file_name_TEResNet_lambda_p_0_250_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.250/dev/events.out.tfevents.1620069407.deagle"
file_name_TEResNet_lambda_p_0_250_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_250/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.250/train/events.out.tfevents.1620069405.deagle"

file_name_TEResNet_lambda_p_0_500_dev   = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.500/dev/events.out.tfevents.1620227197.deagle"
file_name_TEResNet_lambda_p_0_500_train = "/home/manlong/IPython_Notebook/TEGAN/long_new_lambda_p_0_500/TEResNet/summary_RB12_LR0.0001_ENS0.2_CON0.5_PHY0.500/train/events.out.tfevents.1620227195.deagle"

TEResNet_tags = readTFevents.get_tags_from_event(file_name_TEResNet_lambda_p_0_125_dev)

# %%
TEResNet_tags
# Out:
# ['High_resolution/image/0',
#  'Low_resolution/image/0',
#  'Generated/image/0',
#  'Concat/image/0',
#  'Generator_loss',
#  'Content_loss',
#  'Physics_loss',
#  'MSE_error',
#  'Continuity_error',
#  'Pressure_error',
#  'TKE_error',
#  'Enstrophy_error',
#  'Z_-_Continuity_residual/image/0',
#  'Z_-_Pressure_residual/image/0',
#  'Learning_rate']

# %%
TEResNet_long_physics_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_dev, tag='Physics_loss')
TEResNet_long_physics_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Physics_loss')

TEResNet_long_physics_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_dev, tag='Physics_loss')
TEResNet_long_physics_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Physics_loss')

TEResNet_long_physics_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_dev, tag='Physics_loss')
TEResNet_long_physics_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Physics_loss')

TEResNet_long_physics_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_dev, tag='Physics_loss')
TEResNet_long_physics_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Physics_loss')

plt.figure(figsize=(6,4))
plt.semilogy(TEResNet_long_physics_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_p=0.000$')
plt.semilogy(TEResNet_long_physics_loss_labmda_p_0_125_train, '--', label=r'$\lambda_p=0.125$')
plt.semilogy(TEResNet_long_physics_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_p=0.250$')
plt.semilogy(TEResNet_long_physics_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_p=0.500$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{physics}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(4.0e-5, 1.0e2)

plt.tight_layout()
plt.savefig('TEResNet_physics_loss.pdf')
plt.show()

# %%
TEResNet_long_continuity_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_dev, tag='Continuity_error')
TEResNet_long_continuity_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Continuity_error')

TEResNet_long_continuity_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_dev, tag='Continuity_error')
TEResNet_long_continuity_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Continuity_error')

TEResNet_long_continuity_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_dev, tag='Continuity_error')
TEResNet_long_continuity_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Continuity_error')

TEResNet_long_continuity_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_dev, tag='Continuity_error')
TEResNet_long_continuity_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Continuity_error')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_long_continuity_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_p=0.000$')
plt.plot(TEResNet_long_continuity_loss_labmda_p_0_125_train, '--', label=r'$\lambda_p=0.125$')
plt.plot(TEResNet_long_continuity_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_p=0.250$')
plt.plot(TEResNet_long_continuity_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_p=0.500$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{continuity}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.01, 0.2)

plt.tight_layout()
plt.savefig('TEResNet_continuity_loss.pdf')
plt.show()

# %%
TEResNet_long_pressure_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_dev, tag='Pressure_error')
TEResNet_long_pressure_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Pressure_error')

TEResNet_long_pressure_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_dev, tag='Pressure_error')
TEResNet_long_pressure_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Pressure_error')

TEResNet_long_pressure_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_dev, tag='Pressure_error')
TEResNet_long_pressure_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Pressure_error')

TEResNet_long_pressure_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_dev, tag='Pressure_error')
TEResNet_long_pressure_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Pressure_error')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_long_pressure_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_p=0.000$')
plt.plot(TEResNet_long_pressure_loss_labmda_p_0_125_train, '--', label=r'$\lambda_p=0.125$')
plt.plot(TEResNet_long_pressure_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_p=0.250$')
plt.plot(TEResNet_long_pressure_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_p=0.500$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{pressure}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.1, 2.0)

plt.tight_layout()
plt.savefig('TEResNet_pressure_loss.pdf')
plt.show()

# %%
TEResNet_long_content_loss_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_dev, tag='Content_loss')
TEResNet_long_content_loss_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='Content_loss')

TEResNet_long_content_loss_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_dev, tag='Content_loss')
TEResNet_long_content_loss_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='Content_loss')

TEResNet_long_content_loss_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_dev, tag='Content_loss')
TEResNet_long_content_loss_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='Content_loss')

TEResNet_long_content_loss_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_dev, tag='Content_loss')
TEResNet_long_content_loss_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='Content_loss')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_long_content_loss_labmda_p_0_000_train, '-',  label=r'$\lambda_p=0.000$')
plt.plot(TEResNet_long_content_loss_labmda_p_0_125_train, '--', label=r'$\lambda_p=0.125$')
plt.plot(TEResNet_long_content_loss_labmda_p_0_250_train, '-.', label=r'$\lambda_p=0.250$')
plt.plot(TEResNet_long_content_loss_labmda_p_0_500_train, ':',  label=r'$\lambda_p=0.500$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathcal{L}_\mathrm{content}$', fontsize=20)
plt.legend(fontsize=14)
plt.ylim(-0.01, 0.3)

plt.tight_layout()
plt.savefig('TEResNet_content_loss.pdf')
plt.show()

# %%
TEResNet_long_TKE_error_labmda_p_0_000_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_dev, tag='TKE_error')
TEResNet_long_TKE_error_labmda_p_0_000_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_000_train, tag='TKE_error')

TEResNet_long_TKE_error_labmda_p_0_125_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_dev, tag='TKE_error')
TEResNet_long_TKE_error_labmda_p_0_125_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_125_train, tag='TKE_error')

TEResNet_long_TKE_error_labmda_p_0_250_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_dev, tag='TKE_error')
TEResNet_long_TKE_error_labmda_p_0_250_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_250_train, tag='TKE_error')

TEResNet_long_TKE_error_labmda_p_0_500_dev   = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_dev, tag='TKE_error')
TEResNet_long_TKE_error_labmda_p_0_500_train = readTFevents.read_summary_value(file_name_TEResNet_lambda_p_0_500_train, tag='TKE_error')

plt.figure(figsize=(6,4))
plt.plot(TEResNet_long_TKE_error_labmda_p_0_000_train, '-',  label=r'$\lambda_p=0.000$')
plt.plot(TEResNet_long_TKE_error_labmda_p_0_125_train, '--', label=r'$\lambda_p=0.125$')
plt.plot(TEResNet_long_TKE_error_labmda_p_0_250_train, '-.', label=r'$\lambda_p=0.250$')
plt.plot(TEResNet_long_TKE_error_labmda_p_0_500_train, ':',  label=r'$\lambda_p=0.500$')

plt.xlabel(r'$\mathrm{Iterations/10}$', fontsize=20)
plt.ylabel(r'$\mathrm{TKE\ error}$', fontsize=20)
plt.legend(fontsize=14)
# plt.ylim(1.0e-4, 1.0e2)
# plt.title(r'$\mathrm{TEResNet}$',fontsize=16)
plt.show()
